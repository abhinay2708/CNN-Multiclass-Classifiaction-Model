# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
# Load the Dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

# %%
# Normalie the pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# Class Labels
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

print("✅ Dataset loaded successfully!")
print("Training samples:", x_train.shape[0])
print("Test samples:", x_test.shape[0])
# Out:
# ✅ Dataset loaded successfully!
# Training samples: 50000
# Test samples: 10000

# %%
# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# %%
# Visualize some training images
plt.figure(figsize=(10,4))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([]); plt.yticks([])
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
plt.suptitle("Sample CIFAR-10 Images")
plt.show()

# %%
model = models.Sequential([
    layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Show model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 816,938 (3.12 MB)
#  Trainable params: 815,530 (3.11 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(factor=0.5, patience=5, min_lr=1e-6)

history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    steps_per_epoch=len(x_train)//64,
                    epochs=100,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 52s 51ms/step - accuracy: 0.3393 - loss: 2.0869 - val_accuracy: 0.5279 - val_loss: 1.3611 - learning_rate: 0.0010
# Epoch 2/100
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.5625 - loss: 1.2364
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5625 - loss: 1.2364 - val_accuracy: 0.5312 - val_loss: 1.3594 - learning_rate: 0.0010
# Epoch 3/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 63s 39ms/step - accuracy: 0.5557 - loss: 1.2444 - val_accuracy: 0.6348 - val_loss: 1.0832 - learning_rate: 0.0010
# Epoch 4/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5312 - loss: 1.3515 - val_accuracy: 0.6316 - val_loss: 1.0951 - learning_rate: 0.0010
# Epoch 5/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.6308 - loss: 1.0428 - val_accuracy: 0.7170 - val_loss: 0.7992 - learning_rate: 0.0010
# Epoch 6/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7500 - loss: 0.7066 - val_accuracy: 0.7171 - val_loss: 0.8008 - learning_rate: 0.0010
# Epoch 7/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6745 - loss: 0.9243 - val_accuracy: 0.7113 - val_loss: 0.8364 - learning_rate: 0.0010
# Epoch 8/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6562 - loss: 0.9275 - val_accuracy: 0.7069 - val_loss: 0.8492 - learning_rate: 0.0010
# Epoch 9/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7098 - loss: 0.8308 - val_accuracy: 0.6762 - val_loss: 1.0353 - learning_rate: 0.0010
# Epoch 10/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7031 - loss: 0.8829 - val_accuracy: 0.6797 - val_loss: 1.0157 - learning_rate: 0.0010
# Epoch 11/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7373 - loss: 0.7582 - val_accuracy: 0.7683 - val_loss: 0.6951 - learning_rate: 5.0000e-04
# Epoch 12/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.7516 - val_accuracy: 0.7706 - val_loss: 0.6899 - learning_rate: 5.0000e-04
# Epoch 13/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7549 - loss: 0.7045 - val_accuracy: 0.7830 - val_loss: 0.6396 - learning_rate: 5.0000e-04
# Epoch 14/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.6746 - val_accuracy: 0.7798 - val_loss: 0.6487 - learning_rate: 5.0000e-04
# Epoch 15/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7629 - loss: 0.6833 - val_accuracy: 0.8019 - val_loss: 0.5839 - learning_rate: 5.0000e-04
# Epoch 16/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.7778 - val_accuracy: 0.8017 - val_loss: 0.5844 - learning_rate: 5.0000e-04
# Epoch 17/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 39ms/step - accuracy: 0.7757 - loss: 0.6447 - val_accuracy: 0.8026 - val_loss: 0.5870 - learning_rate: 5.0000e-04
# Epoch 18/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7969 - loss: 0.7553 - val_accuracy: 0.8016 - val_loss: 0.5900 - learning_rate: 5.0000e-04
# Epoch 19/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7852 - loss: 0.6289 - val_accuracy: 0.7875 - val_loss: 0.6204 - learning_rate: 5.0000e-04
# Epoch 20/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7656 - loss: 0.5643 - val_accuracy: 0.7883 - val_loss: 0.6199 - learning_rate: 5.0000e-04
# Epoch 21/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8030 - loss: 0.5748 - val_accuracy: 0.8131 - val_loss: 0.5647 - learning_rate: 2.5000e-04
# Epoch 22/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7969 - loss: 0.4950 - val_accuracy: 0.8121 - val_loss: 0.5654 - learning_rate: 2.5000e-04
# Epoch 23/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 38ms/step - accuracy: 0.8044 - loss: 0.5652 - val_accuracy: 0.8309 - val_loss: 0.5060 - learning_rate: 2.5000e-04
# Epoch 24/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8281 - loss: 0.5436 - val_accuracy: 0.8300 - val_loss: 0.5067 - learning_rate: 2.5000e-04
# Epoch 25/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 40ms/step - accuracy: 0.8066 - loss: 0.5549 - val_accuracy: 0.8225 - val_loss: 0.5296 - learning_rate: 2.5000e-04
# Epoch 26/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7812 - loss: 0.5971 - val_accuracy: 0.8232 - val_loss: 0.5277 - learning_rate: 2.5000e-04
# Epoch 27/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.8167 - loss: 0.5363 - val_accuracy: 0.8310 - val_loss: 0.5005 - learning_rate: 2.5000e-04
# Epoch 28/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.6102 - val_accuracy: 0.8313 - val_loss: 0.4996 - learning_rate: 2.5000e-04
# Epoch 29/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.8170 - loss: 0.5258 - val_accuracy: 0.8332 - val_loss: 0.4932 - learning_rate: 2.5000e-04
# Epoch 30/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8438 - loss: 0.4584 - val_accuracy: 0.8338 - val_loss: 0.4939 - learning_rate: 2.5000e-04
# Epoch 31/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.8218 - loss: 0.5181 - val_accuracy: 0.8328 - val_loss: 0.4991 - learning_rate: 2.5000e-04
# Epoch 32/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8281 - loss: 0.5026 - val_accuracy: 0.8325 - val_loss: 0.5004 - learning_rate: 2.5000e-04
# Epoch 33/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 38ms/step - accuracy: 0.8283 - loss: 0.5038 - val_accuracy: 0.8239 - val_loss: 0.5293 - learning_rate: 2.5000e-04
# Epoch 34/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.4240 - val_accuracy: 0.8232 - val_loss: 0.5324 - learning_rate: 2.5000e-04
# Epoch 35/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 40ms/step - accuracy: 0.8307 - loss: 0.4936 - val_accuracy: 0.8321 - val_loss: 0.5070 - learning_rate: 1.2500e-04
# Epoch 36/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7188 - loss: 0.6828 - val_accuracy: 0.8323 - val_loss: 0.5068 - learning_rate: 1.2500e-04
# Epoch 37/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8368 - loss: 0.4785 - val_accuracy: 0.8355 - val_loss: 0.4939 - learning_rate: 1.2500e-04
# Epoch 38/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.4256 - val_accuracy: 0.8354 - val_loss: 0.4939 - learning_rate: 1.2500e-04
# Epoch 39/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 39ms/step - accuracy: 0.8340 - loss: 0.4812 - val_accuracy: 0.8420 - val_loss: 0.4774 - learning_rate: 1.2500e-04
# Epoch 40/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9062 - loss: 0.3278 - val_accuracy: 0.8424 - val_loss: 0.4780 - learning_rate: 1.2500e-04
# Epoch 41/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8364 - loss: 0.4687 - val_accuracy: 0.8450 - val_loss: 0.4731 - learning_rate: 1.2500e-04
# Epoch 42/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8750 - loss: 0.4294 - val_accuracy: 0.8452 - val_loss: 0.4720 - learning_rate: 1.2500e-04
# Epoch 43/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8373 - loss: 0.4737 - val_accuracy: 0.8228 - val_loss: 0.5354 - learning_rate: 1.2500e-04
# Epoch 44/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9062 - loss: 0.3536 - val_accuracy: 0.8217 - val_loss: 0.5380 - learning_rate: 1.2500e-04
# Epoch 45/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8386 - loss: 0.4627 - val_accuracy: 0.8482 - val_loss: 0.4537 - learning_rate: 1.2500e-04
# Epoch 46/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7812 - loss: 0.6214 - val_accuracy: 0.8477 - val_loss: 0.4540 - learning_rate: 1.2500e-04
# Epoch 47/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 40ms/step - accuracy: 0.8402 - loss: 0.4639 - val_accuracy: 0.8447 - val_loss: 0.4701 - learning_rate: 1.2500e-04
# Epoch 48/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8750 - loss: 0.4440 - val_accuracy: 0.8440 - val_loss: 0.4693 - learning_rate: 1.2500e-04
# Epoch 49/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.8386 - loss: 0.4672 - val_accuracy: 0.8466 - val_loss: 0.4608 - learning_rate: 1.2500e-04
# Epoch 50/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8594 - loss: 0.3863 - val_accuracy: 0.8470 - val_loss: 0.4606 - learning_rate: 1.2500e-04
# Epoch 51/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8457 - loss: 0.4474 - val_accuracy: 0.8479 - val_loss: 0.4575 - learning_rate: 6.2500e-05
# Epoch 52/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.4596 - val_accuracy: 0.8477 - val_loss: 0.4578 - learning_rate: 6.2500e-05
# Epoch 53/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8459 - loss: 0.4481 - val_accuracy: 0.8444 - val_loss: 0.4759 - learning_rate: 6.2500e-05
# Epoch 54/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.4603 - val_accuracy: 0.8441 - val_loss: 0.4759 - learning_rate: 6.2500e-05
# Epoch 55/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 39ms/step - accuracy: 0.8495 - loss: 0.4395 - val_accuracy: 0.8483 - val_loss: 0.4615 - learning_rate: 6.2500e-05

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"\n🎯 Test Accuracy: {test_acc:.4f}")
# Out:
# 🎯 Test Accuracy: 0.8482

# %%
# Plot the training results

plt.figure(figsize=(12,4))

# Accuracy plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs'); plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()

# Loss plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs'); plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()

# %%
# Predict on text images

plt.figure(figsize=(10,5))
for i in range(5):
    idx = np.random.randint(0, len(x_test))
    img = x_test[idx]
    label = y_test[idx][0]
    pred = np.argmax(model.predict(img.reshape(1,32,32,3)))

    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Pred: {class_names[pred]}\nTrue: {class_names[label]}")
plt.suptitle("Model Predictions on Test Images")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
def predict_custom_image(img_path):
    # Load and preprocess
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img, (32,32)) / 255.0
    img_array = np.expand_dims(img_resized, axis=0)

    # Predict
    pred_probs = model.predict(img_array)[0]
    pred_class = np.argmax(pred_probs)

    # Show image
    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {class_names[pred_class]} ({pred_probs[pred_class]*100:.2f}%)")
    plt.show()
predict_custom_image("/images (3).jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
# Save the model
model.save("cifar10_cnn.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("cifar10_cnn.h5")
